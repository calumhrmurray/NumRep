# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt("/home/pclarke/Teaching/NumericalRecipes/Unit1-Matrices/java/testData.txt")

# %%
plt.figure(figsize=(20,10))
plt.plot([row[0] for row in data],[row[1] for row in data])
plt.plot([row[0] for row in data], [1 for row in data])

# %%
m = 0
c = 1
d_2 = []

for row in data:
    d_2.append(((row[1]-m*row[0]-c)/row[2])**2)
    
print 'm =',m,', c =',1,', chi squared =',np.sum(d_2)
# Out:
# m = 0 , c = 1 , chi squared = 71.0138888889

# %%
m = 0
c = 1
d_2 = []

for row in data:
    d_2.append(((row[1]-m*row[0]-c)/row[2])**2)
    
np.sum(d_2)
# Out:
# 71.013888888888999

# %%
class Linear:
    
    def __init__(self):
        self.m = 0
        self.c = 0
        
    def set_params(self, params):
        if len(params) != 2:
            print('Error - incorrect input parameters')
        else:
            self.m = params[0]
            self.c = params[1]
            
    def evaluate(self, x_list):
        return self.m*x_list + self.c

# %%
class chi_squared:
    
    def __init__(self, xin, yin, ein, function):
        self.x_data = xin
        self.y_data = yin
        self.e_data = ein  
        
        self.function
    
    def setParameters(self,params)
    
    def evaluate
# Out:
# 71.013888888888999
